# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\anuvi\OneDrive\Desktop\census_2011 (1).csv')

# %%
df.head()
# Out:
#    District code         State name District name  Population      Male  \
# 0              1  JAMMU AND KASHMIR       Kupwara    870354.0  474190.0
# 1              2  JAMMU AND KASHMIR        Badgam    753745.0       NaN
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)    133487.0   78971.0
# 3              4  JAMMU AND KASHMIR        Kargil    140802.0       NaN
# 4              5  JAMMU AND KASHMIR         Punch         NaN  251899.0
#
#      Female  Literate  Male_Literate  Female_Literate      SC  ...  \
# 0  396164.0  439654.0       282823.0         156831.0  1048.0  ...
# 1  355704.0  335649.0       207741.0         127908.0     NaN  ...
# 2   54516.0   93770.0        62834.0          30936.0   488.0  ...
# 3   63017.0       NaN        56301.0          29935.0    18.0  ...
# 4  224936.0  261724.0       163333.0          98391.0   556.0  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                          94.0                         588.0
# ...

# %%
df.describe()
# Out:
#        District code    Population          Male        Female      Literate  \
# count     640.000000  6.100000e+02  6.100000e+02  6.070000e+02  6.040000e+02
# mean      320.500000  1.852620e+06  9.685726e+05  9.139882e+05  1.190550e+06
# std       184.896367  1.435578e+06  7.926455e+05  7.479293e+05  1.050630e+06
# min         1.000000  8.004000e+03  4.414000e+03  3.590000e+03  4.436000e+03
# 25%       160.750000  8.148625e+05  4.180382e+05  3.986990e+05  4.796545e+05
# 50%       320.500000  1.557367e+06  7.939620e+05  7.556020e+05  9.793575e+05
# 75%       480.250000  2.565248e+06  1.318615e+06  1.253832e+06  1.602260e+06
# max       640.000000  1.000978e+07  5.865078e+06  5.195070e+06  8.227161e+06
#
#        Male_Literate  Female_Literate            SC       Male_SC  \
# count   6.090000e+02     6.130000e+02  6.050000e+02  6.170000e+02
# mean    6.739088e+05     5.129481e+05  3.177854e+05  1.624509e+05
# std     5.683384e+05     4.801441e+05  3.172010e+05  1.625607e+05
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Columns: 118 entries, District code to Total_Power_Parity
# dtypes: float64(115), int64(1), object(2)
# memory usage: 590.1+ KB

# %%
rename_columns = {
    'State name': 'State/UT',
    'District name': 'District',
    'Male_Literate': 'Literate_Male',
    'Female_Literate': 'Literate_Female',
    'Rural_Households': 'Households_Rural',
    'Urban_Households': 'Households_Urban',
    'Age_Group_0_29': 'Young_and_Adult',
    'Age_Group_30_49': 'Middle_Aged',
    'Age_Group_50': 'Senior_Citizen',
    'Age not stated': 'Age_Not_Stated'
}

# %%
df.rename(columns=rename_columns, inplace=True)
df.head()
# Out:
#    District code           State/UT     District  Population      Male  \
# 0              1  JAMMU AND KASHMIR      Kupwara    870354.0  474190.0
# 1              2  JAMMU AND KASHMIR       Badgam    753745.0       NaN
# 2              3  JAMMU AND KASHMIR  Leh(Ladakh)    133487.0   78971.0
# 3              4  JAMMU AND KASHMIR       Kargil    140802.0       NaN
# 4              5  JAMMU AND KASHMIR        Punch         NaN  251899.0
#
#      Female  Literate  Literate_Male  Literate_Female      SC  ...  \
# 0  396164.0  439654.0       282823.0         156831.0  1048.0  ...
# 1  355704.0  335649.0       207741.0         127908.0     NaN  ...
# 2   54516.0   93770.0        62834.0          30936.0   488.0  ...
# 3   63017.0       NaN        56301.0          29935.0    18.0  ...
# 4  224936.0  261724.0       163333.0          98391.0   556.0  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                          94.0                         588.0
# ...

# %%
df.head()
# Out:
#    District code           State/UT     District  Population      Male  \
# 0              1  JAMMU AND KASHMIR      Kupwara    870354.0  474190.0
# 1              2  JAMMU AND KASHMIR       Badgam    753745.0       NaN
# 2              3  JAMMU AND KASHMIR  Leh(Ladakh)    133487.0   78971.0
# 3              4  JAMMU AND KASHMIR       Kargil    140802.0       NaN
# 4              5  JAMMU AND KASHMIR        Punch         NaN  251899.0
#
#      Female  Literate  Literate_Male  Literate_Female      SC  ...  \
# 0  396164.0  439654.0       282823.0         156831.0  1048.0  ...
# 1  355704.0  335649.0       207741.0         127908.0     NaN  ...
# 2   54516.0   93770.0        62834.0          30936.0   488.0  ...
# 3   63017.0       NaN        56301.0          29935.0    18.0  ...
# 4  224936.0  261724.0       163333.0          98391.0   556.0  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                          94.0                         588.0
# ...

# %%
#Replacing place names
df.replace(

    to_replace="ANDAMAN AND NICOBAR ISLANDS",
    value="Andaman and Nicobar Islands",inplace=True
)

# %%
df.replace(

    to_replace="JAMMU AND KASHMIR",
    value="Jammu and Kashmir",inplace=True
)

# %%
df.head()
# Out:
#    District code           State/UT     District  Population      Male  \
# 0              1  Jammu and Kashmir      Kupwara    870354.0  474190.0
# 1              2  Jammu and Kashmir       Badgam    753745.0       NaN
# 2              3  Jammu and Kashmir  Leh(Ladakh)    133487.0   78971.0
# 3              4  Jammu and Kashmir       Kargil    140802.0       NaN
# 4              5  Jammu and Kashmir        Punch         NaN  251899.0
#
#      Female  Literate  Literate_Male  Literate_Female      SC  ...  \
# 0  396164.0  439654.0       282823.0         156831.0  1048.0  ...
# 1  355704.0  335649.0       207741.0         127908.0     NaN  ...
# 2   54516.0   93770.0        62834.0          30936.0   488.0  ...
# 3   63017.0       NaN        56301.0          29935.0    18.0  ...
# 4  224936.0  261724.0       163333.0          98391.0   556.0  ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# 0                          94.0                         588.0
# ...

# %%
df.isna()
# Out:
#      District code  State/UT  District  Population   Male  Female  Literate  \
# 0            False     False     False       False  False   False     False
# 1            False     False     False       False   True   False     False
# 2            False     False     False       False  False   False     False
# 3            False     False     False       False   True   False      True
# 4            False     False     False        True  False   False     False
# ..             ...       ...       ...         ...    ...     ...       ...
# 635          False     False     False       False  False   False     False
# 636          False     False     False       False  False   False     False
# 637          False     False     False       False  False    True     False
# 638          False     False     False       False  False   False     False
# 639          False     False     False        True  False   False     False
#
# ...

# %%
li=["Adilabad","Nizamabad","Karimnagar","Medak","Hyderabad","Rangareddy","Mahbubnagar","Nalgonda","Warangal","Khammam"]

# %%
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/164.2 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/164.2 kB ? eta -:--:--
#      ---------------------------- --------- 122.9/164.2 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------- 164.2/164.2 kB 1.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    - -------------------------------------- 0.4/8.0 MB 11.6 MB/s eta 0:00:01
#    --- ------------------------------------ 0.8/8.0 MB 10.0 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.9/8.0 MB 8.1 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/8.0 MB 8.0 MB/s eta 0:00:01
#    --------- ------------------------------ 1.9/8.0 MB 8.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.4/8.0 MB 8.9 MB/s eta 0:00:01
#    ------------ --------------------------- 2.5/8.0 MB 8.5 MB/s eta 0:00:01
# ...

# %%
a=df.isna().sum()

# %%
import matplotlib.pyplot as plt
a
# Out:
# District code                     0
# State/UT                          0
# District                          0
# Population                       30
# Male                             30
#                                  ..
# Power_Parity_Rs_330000_425000    33
# Power_Parity_Rs_425000_545000    30
# Power_Parity_Rs_330000_545000    23
# Power_Parity_Above_Rs_545000     30
# Total_Power_Parity               32
# Length: 118, dtype: int64

# %%
a.hist()
# Out:
# <Axes: >

# %%
#fill missing values
def fillvalues(df):
    df['Population']=df['Population'].fillna(df['Male']+df['Female'])
    df['Literate']=df['Literate'].fillna(df['Literate_Male']+df['Literate_Female'])
    df['Households']=df['Households'].fillna(df['Households_Rural']+df['Households_Urban'])
    df['Male']=df['Male'].fillna(df['Male'].mean())
    df['Literate_Male']=df['Literate_Male'].fillna(df['Literate_Male'].mean())
    df['Literate_Female']=df['Literate_Female'].fillna(df['Literate_Female'].mean())
    df['Marginal_Workers']=df['Marginal_Workers'].fillna(df['Marginal_Workers'].mean())

    return df

data_filled=fillvalues(df)

# %%
#calculating percentage of missing values
intial_percentage=df.isnull().mean()*100
final_percentage=data_filled.isnull().mean()*100
print("Initial missing data percentage:")
print(intial_percentage)
print("\n")
print("Filled data missing percentage:")
print(final_percentage)
# Out:
# Initial missing data percentage:
# District code                    0.00000
# State/UT                         0.00000
# District                         0.00000
# Population                       0.15625
# Male                             0.00000
#                                   ...
# Power_Parity_Rs_330000_425000    5.15625
# Power_Parity_Rs_425000_545000    4.68750
# Power_Parity_Rs_330000_545000    3.59375
# Power_Parity_Above_Rs_545000     4.68750
# Total_Power_Parity               5.00000
# Length: 118, dtype: float64
#
#
# Filled data missing percentage:
# District code                    0.00000
# State/UT                         0.00000
# District                         0.00000
# Population                       0.15625
# Male                             0.00000
#                                   ...
# Power_Parity_Rs_330000_425000    5.15625
# Power_Parity_Rs_425000_545000    4.68750
# Power_Parity_Rs_330000_545000    3.59375
# Power_Parity_Above_Rs_545000     4.68750
# ...

# %%
# !python -m pip install "pymongo[srv]"
# Out:
# ...
#   Using cached pymongo-4.7.2-cp312-cp312-win_amd64.whl.metadata (22 kB)
# ...
#   Using cached dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Using cached dnspython-2.6.1-py3-none-any.whl (307 kB)
# Using cached pymongo-4.7.2-cp312-cp312-win_amd64.whl (485 kB)
# ...

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
uri = "mongodb+srv://anuvind411:Anu1234@cluster0.dexzjxq.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
b=data_filled.isna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1280 entries, 0 to 1279
# Columns: 119 entries, _id to Total_Power_Parity
# dtypes: float64(115), int64(1), object(3)
# memory usage: 1.2+ MB

# %%
li=[]
a=df.dtypes
for i in a:
    li.append(i)
li
# Out:
# [dtype('O'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
# ...

# %%
mydb=client["my_database"]
db=client.lal
records=db.salam

# %%
data=data_filled.to_dict(orient ='records')

# %%
db=client['cencus']
collection=db['census']
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('6665a42b47002e76d7804f10'), ObjectId('6665a42b47002e76d7804f11'), ObjectId('6665a42b47002e76d7804f12'), ObjectId('6665a42b47002e76d7804f13'), ObjectId('6665a42b47002e76d7804f14'), ObjectId('6665a42b47002e76d7804f15'), ObjectId('6665a42b47002e76d7804f16'), ObjectId('6665a42b47002e76d7804f17'), ObjectId('6665a42b47002e76d7804f18'), ObjectId('6665a42b47002e76d7804f19'), ObjectId('6665a42b47002e76d7804f1a'), ObjectId('6665a42b47002e76d7804f1b'), ObjectId('6665a42b47002e76d7804f1c'), ObjectId('6665a42b47002e76d7804f1d'), ObjectId('6665a42b47002e76d7804f1e'), ObjectId('6665a42b47002e76d7804f1f'), ObjectId('6665a42b47002e76d7804f20'), ObjectId('6665a42b47002e76d7804f21'), ObjectId('6665a42b47002e76d7804f22'), ObjectId('6665a42b47002e76d7804f23'), ObjectId('6665a42b47002e76d7804f24'), ObjectId('6665a42b47002e76d7804f25'), ObjectId('6665a42b47002e76d7804f26'), ObjectId('6665a42b47002e76d7804f27'), ObjectId('6665a42b47002e76d7804f28'), ObjectId('6665a42b47002e76d780
# ...

# %%
#data collection from sql
mongo_db=client['cencus']
mongo_collection = mongo_db['census']

mongo_data = list(mongo_collection.find())

# %%
df = pd.DataFrame(mongo_data)
df.dtypes
# Out:
# _id                               object
# District code                      int64
# State/UT                          object
# District                          object
# Population                       float64
#                                   ...
# Power_Parity_Rs_330000_425000    float64
# Power_Parity_Rs_425000_545000    float64
# Power_Parity_Rs_330000_545000    float64
# Power_Parity_Above_Rs_545000     float64
# Total_Power_Parity               float64
# Length: 119, dtype: object

# %%
df = df.drop(columns=['_id'], errors='ignore')
df
# Out:
#       District code                     State/UT                   District  \
# 0                 1            Jammu and Kashmir                    Kupwara
# 1                 2            Jammu and Kashmir                     Badgam
# 2                 3            Jammu and Kashmir                Leh(Ladakh)
# 3                 4            Jammu and Kashmir                     Kargil
# 4                 5            Jammu and Kashmir                      Punch
# ...             ...                          ...                        ...
# 1275            636                  PONDICHERRY                       Mahe
# 1276            637                  PONDICHERRY                   Karaikal
# 1277            638  Andaman and Nicobar Islands                   Nicobars
# 1278            639  Andaman and Nicobar Islands  North  AND Middle Andaman
# 1279            640  Andaman and Nicobar Islands              South Andaman
#
# ...

# %%
# !pip install mysql
# Out:
# ...
#    ---------------------------------------- 0.0/203.3 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/203.3 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/203.3 kB ? eta -:--:--
#    ----- --------------------------------- 30.7/203.3 kB 262.6 kB/s eta 0:00:01
#    ----------------- --------------------- 92.2/203.3 kB 585.1 kB/s eta 0:00:01
#    ------------------------------------ - 194.6/203.3 kB 985.7 kB/s eta 0:00:01
#    -------------------------------------- 203.3/203.3 kB 881.5 kB/s eta 0:00:00
# ...

# %%
# !pip install mysql-connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      --------------------------------------- 0.0/11.9 MB 262.6 kB/s eta 0:00:46
#      --------------------------------------- 0.1/11.9 MB 328.2 kB/s eta 0:00:36
#      --------------------------------------- 0.1/11.9 MB 504.4 kB/s eta 0:00:24
#       -------------------------------------- 0.2/11.9 MB 700.2 kB/s eta 0:00:17
#       -------------------------------------- 0.3/11.9 MB 874.6 kB/s eta 0:00:14
#      - -------------------------------------- 0.4/11.9 MB 1.1 MB/s eta 0:00:11
#      - -------------------------------------- 0.4/11.9 MB 1.1 MB/s eta 0:00:10
#      - -------------------------------------- 0.5/11.9 MB 1.3 MB/s eta 0:00:09
# ...

# %%
import mysql.connector

mydb = mysql.connector.connect(
 host="localhost",
 user="root",
 password="",
 database='db'


)
print(mydb)
mycursor = mydb.cursor(buffered=True)

# %%
# !pip install sqlalchemy
# !pip install pymysql

# %%
from sqlalchemy import create_engine

# %%
mysql_engine =create_engine('mysql+pymysql://root:@localhost:3306/db')

# %%
df.to_sql(name='census_data', con=mycursor, if_exists='replace', index=False)
# Out:
# C:\Users\anuvi\AppData\Local\Temp\ipykernel_1908\2836265169.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df.to_sql(name='census_data', con=mycursor, if_exists='replace', index=False)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 df.to_sql(name='census_data', con=mycursor, if_exists='replace', index=False)
#
# File d:\Python\New folder\.venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
# ...

# %%
y=[]
for i in range(len(df)):
    x=tuple(df.iloc[i])
    y.append(x)

# %%
# !pip install tabulate
# Out:
# ...
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# ...

# %%
out=mycursor.fetchall()
from tabulate import tabulate

print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------+
# | index   |
# |---------|
# +---------+

# %%
file=open('census_data.txt','w')
for tuple in y:
    file.write(str(tuple) + ',' + '\n')
file.close()
